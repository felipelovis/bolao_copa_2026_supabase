# %%
from supabase import create_client

# Configurações do seu projeto (pegue na aba API do Supabase)
url = "https://silwyysyzalfcnmaxqbh.supabase.co"
key = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6InNpbHd5eXN5emFsZmNubWF4cWJoIiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjM2MDY5ODcsImV4cCI6MjA3OTE4Mjk4N30.kQwIioycFbPOLzdzn_adJ65ty0vIDzEPqibcDec_8yk"
supabase = create_client(url, key)

participantes = [
    {"nome": "Felipe", "email": "felipevlovison@hotmail.com", "bolao": "SM3"},
]

# Faz o insert de uma vez só
data = supabase.table("convites").insert(participantes).execute()

print("Dados inseridos com sucesso!")
# Out:
# Dados inseridos com sucesso!
